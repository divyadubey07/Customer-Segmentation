# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("C:\\Users\\Dell\\Desktop\\SIP Data Set\\archive (8)\\Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
sns.catplot(y="Annual Income (k$)" , x='Gender', data=df)

# %%
sns.barplot(y="Annual Income (k$)" , x='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Annual Income (k$)'>

# %%
df['Income_cat'] = pd.cut(df['Annual Income (k$)'],bins=3,labels=['low','medium','high'])

# %%
sns.pairplot(df)

# %%
sns.countplot(df["Income_cat"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income_cat', ylabel='count'>

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#   Income_cat
# 0        low
# 1        low
# 2        low
# 3        low
# 4        low

# %%
sns.boxplot(x='Income_cat',y='Spending Score (1-100)',data=df, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Income_cat', ylabel='Spending Score (1-100)'>

# %%
sns.relplot(x='', y='' , hue='')
